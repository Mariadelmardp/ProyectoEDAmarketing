# %%
import pandas as pd
import numpy as np
# Estaqblecer la visualizacion de todas las columnas
pd.set_option('display.max_columns', None)

# Establecer el formato para números de punto flotante
pd.options.display.float_format = lambda x: '%.4f' % x

# Paquetes d visualización
import seaborn as sns
import matplotlib.pyplot as plt 

import sys
sys.path.append('..')
from src import soporte_analisis as sp

# %%
df=pd.read_csv('../data/nulos_categoricas.csv', parse_dates=['date'])
df.head()
# Out:
#    campaign_id              company campaign_type  duration channel_used  \
# 0            1  innovate industries        Unknow   30.0000   google ads
# 1            2       nexgen systems         email   60.0000   google ads
# 2            3    alpha innovations    influencer   30.0000      youtube
# 3            4               Unknow       display   60.0000      youtube
# 4            5       nexgen systems         email   15.0000      youtube
#
#    conversion_rate     roi     location  language      clicks   impressions  \
# 0           0.0404  6.2900      chicago   spanish         NaN 19221922.0000
# 1           0.1212  5.6100     new york    german    116.0000     7523.0000
# 2           0.0707  7.1800  los angeles    french         NaN     7698.0000
# 3           0.1111     NaN        miami  mandarin    217.0000           NaN
# 4           0.0505 66.5500  los angeles    Unknow 379379.0000     4201.0000
#
#    engagement_score     customer_segment       date   total($)   genre  \
# 0           66.0000    health & wellness 2021-01-01 16174.0000     men
# 1            7.0000         fashionistas 2021-01-02 11566.0000   women
# 2           11.0000  outdoor adventurers 2021-01-03 10200.0000     men
# 3            7.0000    health & wellness 2021-01-04 12724.0000  Unknow
# 4           33.0000    health & wellness 2021-01-05 16452.0000     men
#
#        ages      year  month  day_name  quarter
# 0     18-24 2021.0000 1.0000    friday   1.0000
# 1     35-44 2021.0000 1.0000  saturday   1.0000
# 2     25-34 2021.0000 1.0000    sunday   1.0000
# 3  all_ages 2021.0000 1.0000    monday   1.0000
# 4     25-34 2021.0000 1.0000   tuesday   1.0000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209915 entries, 0 to 209914
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   campaign_id       209915 non-null  int64
#  1   company           209915 non-null  object
#  2   campaign_type     209915 non-null  object
#  3   duration          191309 non-null  float64
#  4   channel_used      209915 non-null  object
#  5   conversion_rate   200471 non-null  float64
#  6   roi               173439 non-null  float64
#  7   location          209915 non-null  object
#  8   language          209915 non-null  object
#  9   clicks            178736 non-null  float64
#  10  impressions       188467 non-null  float64
#  11  engagement_score  186051 non-null  float64
#  12  customer_segment  209915 non-null  object
#  13  date              203007 non-null  datetime64[ns]
#  14  total($)          201832 non-null  float64
#  15  genre             209915 non-null  object
#  16  ages              209915 non-null  object
#  17  year              203007 non-null  float64
#  18  month             203007 non-null  float64
#  19  day_name          209915 non-null  object
#  20  quarter           203007 non-null  float64
# dtypes: datetime64[ns](1), float64(10), int64(1), object(9)
# memory usage: 33.6+ MB

# %%
sp.valores_minuscula(df)
df.sample(5)
# Out:
#         campaign_id              company campaign_type  duration channel_used  \
# 105608       105609  innovate industries    influencer   15.0000      website
# 25969         25970    alpha innovations  social media   60.0000      website
# 208794       173032    alpha innovations  social media   15.0000      youtube
# 136062       136063               unknow        search       NaN      youtube
# 99249         99250       nexgen systems        search   15.0000       unknow
#
#         conversion_rate     roi     location  language      clicks  \
# 105608           0.0300 55.8989  los angeles  mandarin 460460.0000
# 25969            0.1100 77.4444        miami    unknow         NaN
# 208794           0.0600 22.1515      houston   english 591591.0000
# 136062           0.1000 66.3535  los angeles   english 547547.0000
# 99249            0.0202  3.2600      houston    french    762.0000
#
#          impressions  engagement_score     customer_segment       date  \
# 105608     9296.0000         1010.0000         fashionistas 2021-05-04
# 25969      6843.0000            1.0000         fashionistas 2021-02-24
# 208794 86838683.0000            5.0000         fashionistas 2021-01-22
# 136062     3411.0000           88.0000  outdoor adventurers 2021-10-10
# 99249  16301630.0000            2.0000              foodies 2021-12-01
#
#          total($)  genre   ages      year   month   day_name  quarter
# 105608 16631.0000  women  35-44 2021.0000  5.0000    tuesday   2.0000
# 25969   6194.0000  women  35-44 2021.0000  2.0000  wednesday   1.0000
# 208794 19518.0000  women  35-44 2021.0000  1.0000     friday   1.0000
# 136062  5571.0000    men  25-34 2021.0000 10.0000     sunday   4.0000
# 99249  10933.0000  women  35-44 2021.0000 12.0000  wednesday   4.0000

# %%
df.describe().T
# Out:
#                        count                           mean  \
# campaign_id      209915.0000                    100015.0741
# duration         191309.0000                        37.5035
# conversion_rate  200471.0000                         0.0808
# roi              173439.0000                        27.5304
# clicks           178736.0000                    280253.2882
# impressions      188467.0000                  27614356.6920
# engagement_score 186051.0000                        77.9064
# date                  203007  2021-07-02 01:11:59.851039744
# total($)         201832.0000                     12503.9995
# year             203007.0000                      2021.0000
# month            203007.0000                         6.5275
# quarter          203007.0000                         2.5101
#
#                                   min                  25%  \
# campaign_id                    1.0000           50013.5000
# duration                      15.0000              30.0000
# conversion_rate                0.0100               0.0500
# roi                            2.0000               5.0100
# clicks                       100.0000             552.0000
# impressions                 1000.0000            5508.0000
# engagement_score               1.0000               5.0000
# date              2021-01-01 00:00:00  2021-04-02 00:00:00
# total($)                    5000.0000            8740.0000
# year                        2021.0000            2021.0000
# month                          1.0000               4.0000
# quarter                        1.0000               2.0000
#
#                                   50%                  75%  \
# campaign_id               100018.0000          150065.5000
# duration                      30.0000              45.0000
# conversion_rate                0.0808               0.1200
# roi                            8.0000              55.0000
# clicks                    101101.0000          548548.0000
# impressions                 9996.0000        55235523.0000
# engagement_score              10.0000              66.0000
# date              2021-07-02 00:00:00  2021-10-01 00:00:00
# total($)                   12496.0000           16261.0000
# year                        2021.0000            2021.0000
# month                          7.0000              10.0000
# quarter                        3.0000               4.0000
#
#                                   max           std
# campaign_id               200000.0000    57747.9842
# duration                      60.0000       16.7443
# conversion_rate                0.1515        0.0410
# roi                           88.0000       26.1923
# clicks                  10001000.0000   399127.9838
# impressions           1000010000.0000 34140998.4982
# engagement_score            1010.0000      215.8253
# date              2021-12-31 00:00:00           NaN
# total($)                   20000.0000     4338.1943
# year                        2021.0000        0.0000
# month                         12.0000        3.4465
# quarter                        4.0000        1.1162

# %%
col_num= df.select_dtypes(include=np.number).columns.tolist()
lista_eliminar= ['campaign_id', 'year', 'month', 'quarter']
for col in lista_eliminar:
  col_num.remove(col)

# %%
df[col_num].describe().T
# Out:
#                        count          mean           std       min       25%  \
# duration         191309.0000       37.5035       16.7443   15.0000   30.0000
# conversion_rate  200471.0000        0.0808        0.0410    0.0100    0.0500
# roi              173439.0000       27.5304       26.1923    2.0000    5.0100
# clicks           178736.0000   280253.2882   399127.9838  100.0000  552.0000
# impressions      188467.0000 27614356.6920 34140998.4982 1000.0000 5508.0000
# engagement_score 186051.0000       77.9064      215.8253    1.0000    5.0000
# total($)         201832.0000    12503.9995     4338.1943 5000.0000 8740.0000
#
#                          50%           75%             max
# duration             30.0000       45.0000         60.0000
# conversion_rate       0.0808        0.1200          0.1515
# roi                   8.0000       55.0000         88.0000
# clicks           101101.0000   548548.0000   10001000.0000
# impressions        9996.0000 55235523.0000 1000010000.0000
# engagement_score     10.0000       66.0000       1010.0000
# total($)          12496.0000    16261.0000      20000.0000

# %%
num_graph = len(col_num)
num_rows= (num_graph + 2) //3

fig, axes= plt.subplots(num_rows, 3, figsize=(15, num_rows*5))
axes= axes.flatten()
for i, col in enumerate(col_num):
  sns.histplot(data=df, x= col, ax= axes[i], bins= 200)
  axes[i].text(0.8,0.9, f'Media:{round(df[col].mean(),4)}', horizontalalignment='center', verticalalignment='center',transform=axes[i].transAxes)
  axes[i].text(0.8,0.8, f'Media:{df[col].median()}', horizontalalignment='center', verticalalignment='center',transform=axes[i].transAxes)

  axes[i].set_title(f'Distribución de {col}')
  axes[i].set_ylabel('Frecuencia')
  
for j in range (i+1, len(axes)):
  fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
num_graph = len(col_num)
num_rows= (num_graph + 2) //3

fig, axes= plt.subplots(num_rows, 3, figsize=(15, num_rows*5))
axes= axes.flatten()
for i, col in enumerate(col_num):
  sns.boxplot(data=df, x= col, ax= axes[i])

  axes[i].set_title(f'Boxplot de {col}')

for j in range (i+1, len(axes)):
  fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
def subplot_col_num (df, col):
  num_graph = len(col)
  num_rows= (num_graph + 2) //2

  fig, axes= plt.subplots(num_graph, 2, figsize=(15, num_rows*5))

  for i, col in enumerate(col):
    sns.histplot(data=df, x= col, ax= axes[i,0], bins= 200)
    axes[i,0].set_title(f'Distribución de {col}')
    axes[i,0].set_ylabel('Frecuencia')
    
    sns.boxplot(data=df, x= col, ax= axes[i,1])
    axes[i,1].set_title(f'Boxplot de {col}')
    
  for j in range (i+1, len(axes)):
    fig.delaxes(axes[j])

  plt.tight_layout()
  plt.show()

# %% [markdown]
# # Gestión de outliers, como se ha podido ver que tenemos outlier vamos a sacar la cantidad exacta para ver si se pueden eliminar o no.

# %%
df['impressions'][df['impressions']>800000000].count()
# Out:
# np.int64(14)

# %%
# Para poder realizar el estudio de todas la variable es conveniente hacer un diccionario con las condiciones de cada una.add()
dicc_outliers= {'impressions': 800000000,
                'clicks': 8000000,
                'engagement_score': 800}

# %%
for col, out in dicc_outliers.items():
  outliers=df[col][df[col]>out].count()
  print(f'Para la columna{col.upper()} tenemos {outliers}, lo que representa un {round(outliers/df.shape[0]*100,4)} % de los valores')
# Out:
# Para la columnaIMPRESSIONS tenemos 0, lo que representa un 0.0 % de los valores
# Para la columnaCLICKS tenemos 0, lo que representa un 0.0 % de los valores
# Para la columnaENGAGEMENT_SCORE tenemos 9284, lo que representa un 4.4227 % de los valores

# %%
df['clicks']=df['clicks'].apply(lambda x :np.nan if x >8000000 else x )
df['impressions']=df['impressions'].apply(lambda x :np.nan if x >800000000 else x )

# %%
df.to_csv('../data/col_numericas_outliers.csv', index=False)
