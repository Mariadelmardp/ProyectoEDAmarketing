# %%
import pandas as pd
import numpy as np

import sys
sys.path.append('..')
from src import soporte_analisis as sp

# %%
df=pd.read_csv('../data/data_transformacion_limpieza.csv')

# %%
sp.eda_preliminar(df)
# Out:
#         campaign_id             company campaign_type target_audience  \
# 1280           1281      NexGen Systems         Email             NaN
# 83551         83552  DataTech Solutions        Search             NaN
# 48844         48845      NexGen Systems    Influencer       Men 18-24
# 46762         46763            TechCorp         Email     Women 25-34
# 137160       137161   Alpha Innovations    Influencer       Men 18-24
#
#        duration channel_used conversion_rate acquisition_cost      roi  \
# 1280        NaN        Email         00.0707       $13,432.00      NaN
# 83551       NaN    Instagram            0,04       $17,373.00  33.8282
# 48844   60 days        Email         00.0202        $8,788.00      7,3
# 46762   30 days        Email           00.11              NaN     6,28
# 137160  60 days      Website         00.1212       $12,720.00  77.2323
#
#            location  language     clicks  impressions engagement_score  \
# ...

# %%
sp.valores_minuscula(df)

# %%
df['duration']=df['duration'].apply(lambda x: x.split()[0] if isinstance(x, str) else x)

# %%
sp.dolares(df, lista_col=['acquisition_cost', 'total($)'])

# %%
df['acquisition_cost'].equals(df['total($)'])
df.drop('acquisition_cost', axis=1, inplace=True)

# %%
coma=['conversion_rate', 'roi', 'clicks', 'impressions', 'engagement_score']

# %%
sp.comas(df, coma)

# %%
df['target_audience'].unique()
# Out:
# array(['men 18-24', 'women 35-44', 'men 25-34', 'all ages', nan,
#        'women 25-34'], dtype=object)

# %%
df['genre']=df['target_audience'].apply(lambda x: x.split()[0] if isinstance(x, str) else x)
df['ages']=df['target_audience'].apply(lambda x: x.split()[1] if isinstance(x, str) else x)

# %%
df[['genre', 'ages']]=df['target_audience'].str.split(' ', expand=True)

# %%
df['genre']=df['genre'].replace('all',np.nan)
df['ages']=df['ages'].replace('ages','all_ages')
df.drop('target_audience', axis=1, inplace=True)

# %%
sp.convertir_columnas(df, '%Y-%m-%d')

# %%
df['year']=df['date'].dt.year
df['month']=df['date'].dt.month
df['day_name']=df['date'].dt.day_name()
df['quarter']=df['date'].dt.quarter

# %%
sp.valores_minuscula(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209915 entries, 0 to 209914
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   campaign_id       209915 non-null  int64
#  1   company           194734 non-null  object
#  2   campaign_type     191535 non-null  object
#  3   duration          191309 non-null  float64
#  4   channel_used      187421 non-null  object
#  5   conversion_rate   200471 non-null  float64
#  6   roi               173439 non-null  float64
#  7   location          184543 non-null  object
#  8   language          182907 non-null  object
#  9   clicks            178736 non-null  float64
#  10  impressions       188467 non-null  float64
#  11  engagement_score  186051 non-null  float64
#  12  customer_segment  196763 non-null  object
#  13  date              203007 non-null  datetime64[ns]
#  14  total($)          201832 non-null  float64
# ...

# %%
df.to_csv('../data/data_limpios.csv', index=False)
