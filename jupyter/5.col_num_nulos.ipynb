# %%
import pandas as pd
import numpy as np
# Estaqblecer la visualizacion de todas las columnas
pd.set_option('display.max_columns', None)

# Establecer el formato para números de punto flotante
pd.options.display.float_format = lambda x: '%.4f' % x

# Paquetes d visualización
import seaborn as sns
import matplotlib.pyplot as plt 

import sys
sys.path.append('..')
from src import soporte_analisis as spa
from src import sp_visualizacin as spv
from src import sp_eda as spe
from src import sp_nulos as spn

# Librería de gstion de nulos, predictiva
from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer

# %%
df=pd.read_csv('../data/col_numericas_outliers.csv', parse_dates=['date'])

# %%
spe.calcular_porcentaje_nulos(df.select_dtypes(include=np.number))
# Out:
# campaign_id         0.0000
# duration            8.8600
# conversion_rate     4.5000
# roi                17.3800
# clicks             14.9000
# impressions        10.2200
# engagement_score   11.3700
# total($)            3.8500
# year                3.2900
# month               3.2900
# quarter             3.2900
# dtype: float64

# %%
col_hight_umbral, col_low_umbral= spn.gestion_nulos(df.select_dtypes(include=np.number), 5)
# Out:
#              Column Datatype  NullCount   Null%
# 0          duration  float64      18606  8.8636
# 1   conversion_rate  float64       9444  4.4990
# 2               roi  float64      36476 17.3766
# 3            clicks  float64      31274 14.8984
# 4       impressions  float64      21462 10.2241
# 5  engagement_score  float64      23864 11.3684
# 6          total($)  float64       8083  3.8506
# 7              year  float64       6908  3.2909
# 8             month  float64       6908  3.2909
# 9           quarter  float64       6908  3.2909

# %% [markdown]
# Columnas numericas relacionadas con fecha

# %%
lista_col_fecha= ['year', 'month', 'quarter']
spv.subplot_col_num(df, lista_col_fecha)

# %%
df[lista_col_fecha].describe().T
# Out:
#               count      mean    std       min       25%       50%       75%  \
# year    203007.0000 2021.0000 0.0000 2021.0000 2021.0000 2021.0000 2021.0000
# month   203007.0000    6.5275 3.4465    1.0000    4.0000    7.0000   10.0000
# quarter 203007.0000    2.5101 1.1162    1.0000    2.0000    3.0000    4.0000
#
#               max
# year    2021.0000
# month     12.0000
# quarter    4.0000

# %%
col_low_umbral
# Out:
# ['conversion_rate', 'total($)', 'year', 'month', 'quarter']

# %%
df_filled_simple= df.fillna({
  'conversion_rate': df['conversion_rate'].mean(),
  'total($)': df['total($)'].mean(),
  'year': 2021,
  'month': df['month'].median(),
  'quarter': 3
  
})

# %%
spn.gestion_nulos(df_filled_simple[col_low_umbral])
# Out:
# Empty DataFrame
# Columns: [Column, Datatype, NullCount, Null%]
# Index: []
# ([], [])

# %%
df[col_low_umbral].describe().T
# Out:
#                       count       mean       std       min       25%  \
# conversion_rate 200471.0000     0.0808    0.0410    0.0100    0.0500
# total($)        201832.0000 12503.9995 4338.1943 5000.0000 8740.0000
# year            203007.0000  2021.0000    0.0000 2021.0000 2021.0000
# month           203007.0000     6.5275    3.4465    1.0000    4.0000
# quarter         203007.0000     2.5101    1.1162    1.0000    2.0000
#
#                        50%        75%        max
# conversion_rate     0.0808     0.1200     0.1515
# total($)        12496.0000 16261.0000 20000.0000
# year             2021.0000  2021.0000  2021.0000
# month               7.0000    10.0000    12.0000
# quarter             3.0000     4.0000     4.0000

# %% [markdown]
# Comparamos los estadisticos tras la sustitucion de los nulos para ver si hemos tomado buenas decisiones,
#
# como no hay cambios relevantes en los datos procedemos a cambiarlo en el df original con el que estoy trabajando

# %%
df= df.fillna({
  'conversion_rate': df['conversion_rate'].mean(),
  'total($)': df['total($)'].mean(),
  'year': 2021,
  'month': df['month'].median(),
  'quarter': 3
  
})

# %% [markdown]
# # Gestión de nulos con umbral mayor q 5 con IterativaImputer

# %%
def comparativa_metodos_nulos_numericos ( df, lista_columnas):
  iter_imputer= IterativeImputer(max_iter=50, random_state=42)
  data_imputer= iter_imputer.fit_transform(df[lista_columnas])
  new_col= [col + '_iterative' for col in lista_columnas]
  df[new_col]= data_imputer
  imputer_knn= KNNImputer(n_neighbors=5)
  imputer_knn_imputado = imputer_knn.fit_transform(df[lista_columnas])
  col_knn_imputer= [col + '_knn' for col in lista_columnas]
  df[col_knn_imputer]= imputer_knn_imputado
  col_imputados= lista_columnas + col_knn_imputer + new_col
  display (df, col_imputados)
  return df

# %%
comparativa_metodos_nulos_numericos(df, col_hight_umbral)
# Out:
#         campaign_id              company campaign_type  duration channel_used  \
# 0                 1  innovate industries        unknow   30.0000   google ads
# 1                 2       nexgen systems         email   60.0000   google ads
# 2                 3    alpha innovations    influencer   30.0000      youtube
# 3                 4               unknow       display   60.0000      youtube
# 4                 5       nexgen systems         email   15.0000      youtube
# ...             ...                  ...           ...       ...          ...
# 209910       105984    alpha innovations         email   30.0000      youtube
# 209911       186903   datatech solutions  social media   60.0000      website
# 209912        28288             techcorp       display   60.0000       unknow
# 209913        39333  innovate industries       display   15.0000   google ads
# 209914       102813       nexgen systems  social media   30.0000    instagram
#
#         conversion_rate     roi     location  language      clicks  \
# 0                0.0404  6.2900      chicago   spanish         NaN
# 1                0.1212  5.6100     new york    german    116.0000
# 2                0.0707  7.1800  los angeles    french         NaN
# 3                0.1111     NaN        miami  mandarin    217.0000
# 4                0.0505 66.5500  los angeles    unknow 379379.0000
# ...                 ...     ...          ...       ...         ...
# 209910           0.0202 44.4747      chicago   spanish         NaN
# 209911           0.0700  5.0500  los angeles    unknow 834834.0000
# 209912           0.0303  6.3400        miami  mandarin 314314.0000
# 209913           0.0505 33.4747      chicago    german 457457.0000
# 209914           0.0303  2.8500      houston    unknow 747747.0000
#
#          impressions  engagement_score     customer_segment       date  \
# 0      19221922.0000           66.0000    health & wellness 2021-01-01
# 1          7523.0000            7.0000         fashionistas 2021-01-02
# 2          7698.0000           11.0000  outdoor adventurers 2021-01-03
# 3                NaN            7.0000    health & wellness 2021-01-04
# 4          4201.0000           33.0000    health & wellness 2021-01-05
# ...              ...               ...                  ...        ...
# 209910 79087908.0000           77.0000  outdoor adventurers 2021-05-14
# 209911     1774.0000           99.0000              foodies 2021-01-23
# 209912 61466146.0000           44.0000         fashionistas 2021-07-02
# 209913           NaN           11.0000    health & wellness 2021-10-05
# 209914 50905090.0000            8.0000         fashionistas 2021-09-05
#
#          total($)   genre      ages      year   month  day_name  quarter  \
# 0      16174.0000     men     18-24 2021.0000  1.0000    friday   1.0000
# 1      11566.0000   women     35-44 2021.0000  1.0000  saturday   1.0000
# 2      10200.0000     men     25-34 2021.0000  1.0000    sunday   1.0000
# 3      12724.0000  unknow  all_ages 2021.0000  1.0000    monday   1.0000
# 4      16452.0000     men     25-34 2021.0000  1.0000   tuesday   1.0000
# ...           ...     ...       ...       ...     ...       ...      ...
# 209910  9180.0000     men     18-24 2021.0000  5.0000    friday   2.0000
# 209911  6382.0000   women     25-34 2021.0000  1.0000  saturday   1.0000
# 209912 18155.0000     men     18-24 2021.0000  7.0000    friday   3.0000
# 209913 15166.0000   women     25-34 2021.0000 10.0000   tuesday   4.0000
# 209914 16459.0000     men     25-34 2021.0000  9.0000    sunday   3.0000
#
#         duration_iterative  roi_iterative  clicks_iterative  \
# 0                  30.0000         6.2900       274896.0433
# 1                  60.0000         5.6100          116.0000
# 2                  30.0000         7.1800       274462.5242
# 3                  60.0000        27.7217          217.0000
# 4                  15.0000        66.5500       379379.0000
# ...                    ...            ...               ...
# 209910             30.0000        44.4747       276246.7641
# 209911             60.0000         5.0500       834834.0000
# 209912             60.0000         6.3400       314314.0000
# 209913             15.0000        33.4747       457457.0000
# 209914             30.0000         2.8500       747747.0000
#
#         impressions_iterative  engagement_score_iterative  duration_knn  \
# 0               19221922.0000                     66.0000       30.0000
# 1                   7523.0000                      7.0000       60.0000
# 2                   7698.0000                     11.0000       30.0000
# 3               27541008.2197                      7.0000       60.0000
# 4                   4201.0000                     33.0000       15.0000
# ...                       ...                         ...           ...
# 209910          79087908.0000                     77.0000       30.0000
# 209911              1774.0000                     99.0000       60.0000
# 209912          61466146.0000                     44.0000       60.0000
# 209913          27542853.0044                     11.0000       15.0000
# 209914          50905090.0000                      8.0000       30.0000
#
#         roi_knn  clicks_knn  impressions_knn  engagement_score_knn
# 0        6.2900 267276.2000    19221922.0000               66.0000
# 1        5.6100    116.0000        7523.0000                7.0000
# 2        7.1800 193442.4000        7698.0000               11.0000
# 3       27.0926    217.0000    57782200.6000                7.0000
# 4       66.5500 379379.0000        4201.0000               33.0000
# ...         ...         ...              ...                   ...
# 209910  44.4747    480.8000    79087908.0000               77.0000
# 209911   5.0500 834834.0000        1774.0000               99.0000
# 209912   6.3400 314314.0000    61466146.0000               44.0000
# 209913  33.4747 457457.0000    23602728.8000               11.0000
# 209914   2.8500 747747.0000    50905090.0000                8.0000
#
# [209915 rows x 31 columns]
# ['duration',
#  'roi',
#  'clicks',
#  'impressions',
#  'engagement_score',
#  'duration_knn',
#  'roi_knn',
#  'clicks_knn',
#  'impressions_knn',
#  'engagement_score_knn',
#  'duration_iterative',
#  'roi_iterative',
#  'clicks_iterative',
#  'impressions_iterative',
#  'engagement_score_iterative']

# %%
col_imputados =['duration',
 'roi',
 'clicks',
 'impressions',
 'engagement_score',
 'duration_knn',
 'roi_knn',
 'clicks_knn',
 'impressions_knn',
 'engagement_score_knn',
 'duration_iterative',
 'roi_iterative',
 'clicks_iterative',
 'impressions_iterative',
 'engagement_score_iterative']

# %%
df[col_imputados].describe().sort_index(axis=1).T
# Out:
#                                  count          mean           std       min  \
# clicks                     178641.0000   275083.8650   330318.3401  100.0000
# clicks_iterative           209915.0000   275083.7669   304720.3894  100.0000
# clicks_knn                 209915.0000   273915.1091   309861.7437  100.0000
# duration                   191309.0000       37.5035       16.7443   15.0000
# duration_iterative         209915.0000       37.5035       15.9850   15.0000
# duration_knn               209915.0000       37.4795       16.1404   15.0000
# engagement_score           186051.0000       77.9064      215.8253    1.0000
# engagement_score_iterative 209915.0000       77.9071      203.1876    1.0000
# engagement_score_knn       209915.0000       78.7581      206.1326    1.0000
# impressions                188453.0000 27542118.3142 33097499.8431 1000.0000
# impressions_iterative      209915.0000 27542117.2004 31359913.9309 1000.0000
# impressions_knn            209915.0000 28249993.7277 31850707.5188 1000.0000
# roi                        173439.0000       27.5304       26.1923    2.0000
# roi_iterative              209915.0000       27.5299       23.8083    2.0000
# roi_knn                    209915.0000       27.6433       24.3056    2.0000
#
#                                  25%           50%           75%           max
# clicks                      551.0000   100100.0000   548548.0000   999999.0000
# clicks_iterative            630.0000   256256.0000   470470.0000   999999.0000
# clicks_knn                  623.0000   171171.0000   493217.0000   999999.0000
# duration                     30.0000       30.0000       45.0000       60.0000
# duration_iterative           30.0000       37.5220       45.0000       60.0000
# duration_knn                 30.0000       36.0000       45.0000       60.0000
# engagement_score              5.0000       10.0000       66.0000     1010.0000
# engagement_score_iterative    6.0000       22.0000       77.0000     1010.0000
# engagement_score_knn          6.0000       14.0000       66.0000     1010.0000
# impressions                5508.0000     9996.0000 55225522.0000 99999999.0000
# impressions_iterative      6015.0000 20252025.0000 50095009.0000 99999999.0000
# impressions_knn            5999.0000 17324993.8000 52947713.7000 99999999.0000
# roi                           5.0100        8.0000       55.0000       88.0000
# roi_iterative                 5.6400       27.2071       44.3737       88.0000
# roi_knn                       5.5900       22.4343       44.6161       88.0000

# %%
df.drop(['duration_iterative',
 'roi_iterative',
 'clicks_iterative',
 'impressions_iterative',
 'engagement_score_iterative','duration',
 'roi',
 'clicks',
 'impressions',
 'engagement_score'], axis=1, inplace=True)

# %%
df.to_csv('../data/nulos_numericas_limpios.csv', index=False)
